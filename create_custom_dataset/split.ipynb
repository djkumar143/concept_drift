# %%
import pandas as pd
from pathlib import Path

# %%
PROJECT_PATH = Path.cwd().parent
data_path = PROJECT_PATH/"data"/"elec2.csv"
data_path = data_path.as_posix()
print(data_path)
past_data_path = PROJECT_PATH/"data"/"elec2_past_data.csv"
real_time_data_path = PROJECT_PATH/"data"/"elec2_real_time_data.csv"
# Out:
# c:/Users/ASUS/Desktop/Projects_and_research/kafka_pyspark/Projects/concept_drift/data/elec2.csv

# %%
df = pd.read_csv(data_path)
df_past = df[:35000]
df_past.to_csv(past_data_path, index=False)

# %%
df_real_time = df[35000:]
df_real_time.to_csv(real_time_data_path, index=False)
